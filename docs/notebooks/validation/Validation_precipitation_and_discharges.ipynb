# %% [markdown]
# # Validation of the compound flood model
# ## Discharge and rainfall data

# %% [markdown]
# Sources of data for validation:
#
# **Precipitation**
# - Local measurements from meteo stations
# - Satellite products (e.g. TAMSAT, CHIRPS)
#
#
# **River discharges**
# - Global Runoff Data Centre (GRDC)
# - High water marks (local observations, requires interpretation)
