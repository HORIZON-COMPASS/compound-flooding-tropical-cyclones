# %%
# import necessary modules
import os
import sys
import shutil
import numpy as np
import pandas as pd
import geopandas as gpd
from matplotlib import path
import time
import xarray as xr
import xugrid as xu

# Undo below code and specify your folder if you don't run this code under hydromt_sfincs_insider github branch
sys.path.append(os.path.abspath("C:/Intern/SFINCS_Wave/hydromt_sfincs_insiders")) 

from hydromt_sfincs.sfincs import SfincsModel
from hydromt_sfincs import utils
from hydromt.log import setuplog
import hydromt

# %% [markdown]
# **1. Model Initialization**
#
# 1.1. Ensuring updated HydroMT version

# %%
# !hydromt --version
# Out:
# HydroMT version: 0.10.0

# %% [markdown]
# 1.2. Initialize SFINCS Model and Connect It with Data Catalog

# %%
# Specify root_folder and logger_name
from pathlib import Path
root_folder  = Path('sofala_wave_0.2hs')
boundary_folder = Path('boundary_conditions')
logger = setuplog("sfincs_quadtree", log_level=10)

# initialize model
sf_qt = SfincsModel(
    data_libs = ['datacatalog.yml'], 
    root=root_folder, 
    mode="w+", 
    logger=logger
)
# Out:
# 2024-11-04 14:41:28,414 - sfincs_quadtree - log - INFO - HydroMT version: 0.10.0
# 2024-11-04 14:41:28,460 - sfincs_quadtree - data_catalog - INFO - Parsing data catalog from datacatalog.yml
# 2024-11-04 14:41:28,475 - sfincs_quadtree - log - DEBUG - Writing log messages to new file c:\Intern\SFINCS_Wave\COMPASS\SFINCS_Wave\sofala_wave_0.2hs\hydromt.log.
# 2024-11-04 14:41:28,476 - sfincs_quadtree - model_api - INFO - Initializing sfincs model from unknown (vNA).

# %% [markdown]
# Rerun below code if you update your data catalog

# %%
data_catalog  = hydromt.DataCatalog(data_libs = ['datacatalog.yml'])

# %%
data_catalog
# Out:
#                    provider version  \
# name
# gebco                  None    None
# era5_hourly            None    None
# dfm_output_wl_open     None    None
# dfm_output_wl          None    None
# wltot_0.2hs            None    None
# wltot_stockdon         None    None
#
#                                                                  path  \
# name
# gebco               C:\Intern\SFINCS_Wave\COMPASS\SFINCS_Wave\boun...
# era5_hourly         C:\Intern\SFINCS_Wave\COMPASS\SFINCS_Wave\boun...
# dfm_output_wl_open  C:\Intern\SFINCS_Wave\COMPASS\SFINCS_Wave\boun...
# dfm_output_wl       C:\Intern\SFINCS_Sofala\boundary_conditions\DF...
# wltot_0.2hs         C:\Intern\SFINCS_Wave\COMPASS\SFINCS_Wave\boun...
# wltot_stockdon      C:\Intern\SFINCS_Wave\COMPASS\SFINCS_Wave\boun...
#
#                         data_type  driver            category  \
# name
# gebco               RasterDataset  raster          topography
# era5_hourly         RasterDataset  netcdf               meteo
# dfm_output_wl_open     GeoDataset  netcdf  Boundary condition
# dfm_output_wl          GeoDataset  netcdf  Boundary condition
# wltot_0.2hs            GeoDataset  netcdf  Boundary condition
# wltot_stockdon         GeoDataset  netcdf  Boundary condition
#
#                                                        paper_doi  \
# name
# gebco               10.5285/a29c5465-b138-234d-e053-6c86abc040b9
# era5_hourly                                      10.1002/qj.3803
# dfm_output_wl_open                                           NaN
# dfm_output_wl                                                NaN
# wltot_0.2hs                                                  NaN
# wltot_stockdon                                               NaN
#
#                                   paper_ref  \
# name
# gebco               Weatherall et al (2020)
# era5_hourly          Hersbach et al. (2019)
# dfm_output_wl_open                      NaN
# dfm_output_wl                           NaN
# wltot_0.2hs                             NaN
# wltot_stockdon                          NaN
#
#                                                        source_license  \
# name
# gebco               https://www.gebco.net/data_and_products/gridde...
# era5_hourly         https://cds.climate.copernicus.eu/cdsapp/#!/te...
# dfm_output_wl_open                                                NaN
# dfm_output_wl                                                     NaN
# wltot_0.2hs                                                       NaN
# wltot_stockdon                                                    NaN
#
#                                                            source_url  \
# name
# gebco               https://www.bodc.ac.uk/data/open_download/gebc...
# era5_hourly                     https://doi.org/10.24381/cds.adbb2d47
# dfm_output_wl_open                                                NaN
# dfm_output_wl                                                     NaN
# wltot_0.2hs                                                       NaN
# wltot_stockdon                                                    NaN
#
#                                                        source_version   unit  \
# name
# gebco                                                            2020  m+MSL
# era5_hourly         ERA5 hourly data on single levels from 1940 to...    NaN
# dfm_output_wl_open                                                NaN    NaN
# dfm_output_wl                                                     NaN    NaN
# wltot_0.2hs                                                       NaN    NaN
# wltot_stockdon                                                    NaN    NaN
#
#                                                            notes
# name
# gebco                                                        NaN
# era5_hourly         Extracted from Copernicus Climate Data Store
# dfm_output_wl_open                                           NaN
# dfm_output_wl                                                NaN
# wltot_0.2hs                                                  NaN
# wltot_stockdon                                               NaN

# %% [markdown]
# **2.Setup Grid, Dep, and Mask**
#
# 2.1. Import region polygon

# %%
epsg = 32736
quadtree_region = gpd.read_file(boundary_folder / 'gis' / 'bbox.gpkg').to_crs(epsg)
quadtree_refinement = gpd.read_file(boundary_folder / 'gis' / 'refinement_emp.gpkg').to_crs(epsg)

gdf_refinement = gpd.GeoDataFrame(
    {"refinement_level": [1]},
    geometry=[
        quadtree_refinement.geometry.iloc[0]
    ],
    crs=f'EPSG:{epsg}'
)

# %% [markdown]
# 2.2. Making grid

# %%
sf_qt.setup_grid_from_region(
    region={"geom": quadtree_region},  
    res=200,  
    rotated=True, 
    refinement_polygons=gdf_refinement,
)


sf_qt.quadtree.data["level"].ugrid.plot()
# Out:
# 2024-11-04 14:41:28,617 - sfincs_quadtree - basin_mask - DEBUG - Parsed region (kind=geom): {'geom': 'GeoDataFrame [ 631685.14925612 7714854.0234284   793224.91996494 7881678.64915184] (crs = EPSG:32736)'}
# Building mesh ...
# Refining ...
# Time elapsed : 0.9780013561248779 s
# Finding neighbors ...
# Time elapsed : 0.2570042610168457 s
# Setting neighbors left and below ...
# Time elapsed : 0.6329984664916992 s
# Getting uv points ...
# Time elapsed : 1.3850042819976807 s
# Making XUGrid ...
# Got rid of duplicates in 5.1860 seconds
# Made XUGrid in 0.0114 seconds
# Time elapsed : 11.509024858474731 s

# %% [markdown]
# 2.3. Setup dep

# %%
datasets_dep = [{'elevtn': 'gebco'}]
sf_qt.setup_dep(datasets_dep=datasets_dep)
# Out:
# 2024-11-04 14:41:54,863 - sfincs_quadtree - rasterdataset - INFO - Reading gebco raster data from C:\Intern\SFINCS_Wave\COMPASS\SFINCS_Wave\boundary_conditions\topo\gebco_2024_n-13.0_s-25.0_w30.0_e45.0.nc
# 2024-11-04 14:41:54,893 - sfincs_quadtree - rasterdataset - WARNING - IO error while detecting zoom levels: Opening a /vsi file with the netCDF driver requires Linux userfaultfd to be available.
# 2024-11-04 14:41:54,971 - sfincs_quadtree - rasterdataset - DEBUG - Clip to [34.216, -20.653, 35.842, -19.149] (epsg:4326))

# %% [markdown]
# 2.4. Setup Quadtree Mask and WL Boundary

# %%
# Import WL and Empirical Model Mask
emp_wl_bc = gpd.read_file(boundary_folder / 'gis' / 'wavemaker.gpkg').to_crs(epsg)
emp_mask = gpd.read_file(boundary_folder / 'gis' / 'bbox_emp.gpkg').to_crs(epsg)

# %%
emp_wl_bc = emp_wl_bc.buffer(2500)
emp_wl_bc = gpd.GeoDataFrame(geometry=emp_wl_bc, crs=f"EPSG:{epsg}")

# %%
sf_qt.setup_mask_active(
    zmin=-5,
    zmax=111,
    include_mask=emp_mask,
    reset_mask=True
)

sf_qt.setup_mask_bounds(
    btype="waterlevel",
    include_mask=emp_wl_bc,
    zmax=-8,
    zmin=-50,
    reset_bounds=True
)

sf_qt.quadtree.data["msk"].ugrid.plot()
# Out:
# 2024-11-04 14:41:57,954 - sfincs_quadtree - geodataframe - DEBUG - Clip intersects [34.258, -20.652, 35.801, -19.149] (EPSG:4326)
# 2024-11-04 14:41:57,958 - sfincs_quadtree - quadtree - INFO - Building mask ...
# 2024-11-04 14:41:57,959 - sfincs_quadtree - quadtree - INFO - Build new mask for: sfincs ...
# 2024-11-04 14:42:04,272 - sfincs_quadtree - geodataframe - DEBUG - Clip intersects [34.216, -20.653, 35.842, -19.149] (EPSG:4326)
# 2024-11-04 14:42:04,280 - sfincs_quadtree - quadtree - DEBUG - waterlevel (mask=2) boundary cells reset.

# %% [markdown]
# **3. Input Forcing and Specify Observation Points**
#
# 3.1. Specify time

# %%
# Specify the simulation time in the model config
model_time_config = {
    "tref": "20190309 000000", #FILL IN THE REFERENCE TIME (can be any date)
    "tstart": "20190310 000000", #FILL IN THE START TIME OF THE SIMULATION
    "tstop": "20190316 000000", #FILL IN THE END TIME OF THE SIMULATION
    "dtout": 3600, #FILL IN THE TIMESTEP OF THE MAP OUTPUT
    "dthisout" : 3600, #FILL IN THE TIMESTEP OF THE SCALAR OUTPUT
}

sf_qt.setup_config(**model_time_config)
sf_qt.config["tspinup"] = 3600
# Out:
# 2024-11-04 14:42:15,385 - sfincs_quadtree - model_api - DEBUG - Setting model config options.

# %% [markdown]
# 3.2. Specify WL from DFM and Meteo from ERA5

# %%
sf_qt.setup_waterlevel_forcing(
    geodataset='wltot_0.2hs'
)

sf_qt.setup_wind_forcing_from_grid(
    wind = 'era5_hourly'
)

sf_qt.setup_pressure_forcing_from_grid(
    press='era5_hourly'
)
# Out:
# 2024-11-04 14:42:15,586 - sfincs_quadtree - rasterdataset - INFO - Reading era5_hourly netcdf data from C:\Intern\SFINCS_Wave\COMPASS\SFINCS_Wave\boundary_conditions\meteo\era5_{variable}_2019-03.nc
# 2024-11-04 14:42:15,615 - sfincs_quadtree - rasterdataset - DEBUG - Slicing time dim (datetime.datetime(2019, 3, 10, 0, 0), datetime.datetime(2019, 3, 16, 0, 0))
# 2024-11-04 14:42:15,622 - sfincs_quadtree - rasterdataset - DEBUG - Clip to [34.258, -20.652, 35.801, -19.149] (epsg:4326))
# 2024-11-04 14:42:15,624 - sfincs_quadtree - sfincs - DEBUG - Resample wind using nearest_index.
# 2024-11-04 14:42:15,847 - sfincs_quadtree - rasterdataset - INFO - Reading era5_hourly netcdf data from C:\Intern\SFINCS_Wave\COMPASS\SFINCS_Wave\boundary_conditions\meteo\era5_{variable}_2019-03.nc
# 2024-11-04 14:42:15,865 - sfincs_quadtree - rasterdataset - DEBUG - Slicing time dim (datetime.datetime(2019, 3, 10, 0, 0), datetime.datetime(2019, 3, 16, 0, 0))
# 2024-11-04 14:42:15,871 - sfincs_quadtree - rasterdataset - DEBUG - Clip to [34.258, -20.652, 35.801, -19.149] (epsg:4326))
# 2024-11-04 14:42:15,873 - sfincs_quadtree - rasterdataset - DEBUG - Convert units for 1 variables.
# 2024-11-04 14:42:15,885 - sfincs_quadtree - sfincs - DEBUG - Resample pressure using nearest_index.

# %% [markdown]
# 3.3. Specify SPW Input

# %%
# Specify spw file location
spw_dir = boundary_folder / 'spw'
spw_filename =  "cyclone_option_norain.spw"

# Copy spw file to root folder
source_path = Path(spw_dir) / spw_filename
destination_path = root_folder / spw_filename
shutil.copy(source_path, destination_path)
print(f"File copied to: {destination_path}")

# Modify sfincs.inp to include spw
sf_qt.config["spwfile"] = spw_filename
sf_qt.config["utmzone"] = '36s'
# Out:
# File copied to: sofala_wave_0.2hs\cyclone_option_norain.spw

# %%
# The keys to access the model forcing
print(sf_qt.forcing.keys())

# # Plot the forcing
_ = sf_qt.plot_forcing()
# Out:
# dict_keys(['bzs', 'wind10_u', 'wind10_v', 'press_2d'])

# %% [markdown]
# **6. Finalization and Run SFINCS**
#
# 6.1. Setup Obs Point

# %%
# Path to observation points & lines geometries
obs_points_fn = boundary_folder / "gis" / 'obs.geojson'

# Setup observation. merge argument handles whether to override or not
sf_qt.setup_observation_points(locations=obs_points_fn, merge=False)

# Print the keys to access the observation geometries
sf_qt.geoms.keys()
# Out:
# 2024-11-04 14:42:18,910 - sfincs_quadtree - geodataframe - INFO - Reading  vector data from boundary_conditions\gis\obs.geojson
# 2024-11-04 14:42:18,923 - sfincs_quadtree - geodataframe - DEBUG - Clip intersects [631685.149, 7714854.023, 793224.920, 7881678.649] (EPSG:32736)
# dict_keys(['region', 'obs'])

# %% [markdown]
# 6.2. Write Model

# %%
sf_qt.write()
# Out:
# 2024-11-04 14:42:18,976 - sfincs_quadtree - sfincs - INFO - Writing model data to c:\Intern\SFINCS_Wave\COMPASS\SFINCS_Wave\sofala_wave_0.2hs
# 2024-11-04 14:42:19,121 - sfincs_quadtree - sfincs - INFO - Write geom files
# 2024-11-04 14:42:19,126 - sfincs_quadtree - sfincs - INFO - Write vector file(s) for geoms to 'gis' subfolder
# 2024-11-04 14:42:19,138 - sfincs_quadtree - sfincs - INFO - Write forcing files
# 2024-11-04 14:42:19,168 - sfincs_quadtree - sfincs - INFO - Write vector file(s) for forcing.bzs to 'gis' subfolder
# 2024-11-04 14:42:19,571 - sfincs_quadtree - sfincs - WARNING - zsini not in states, skipping

# %%
def print_directory_tree(directory):
    for root, dirs, files in os.walk(directory):
        level = root.replace(directory, '').count(os.sep)
        indent = ' ' * 2 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 2 * (level + 1)
        for f in files:
            print(f'{subindent}+ {f}')

print_directory_tree(sf_qt.root)
# Out:
# sofala_wave_0.2hs/
#   + cyclone_option_norain.spw
#   + hydromt.log
#   + hydromt_data.yml
#   + press_2d.nc
#   + run.bat
#   + sfincs.bnd
#   + sfincs.bzs
#   + sfincs.inp
#   + sfincs.nc
#   + sfincs.obs
#   + wind_2d.nc
#   gis/
#     + bnd.geojson
#     + obs.geojson
#     + region.geojson

# %% [markdown]
# 6.3. Run SFINCS

# %%
cur_dir = os.getcwd()

# # uncomment to run sfincs
os.chdir(root_folder)
os.system("run.bat")
os.chdir(cur_dir)

# %%
import xugrid as xu

uds = xu.open_dataset(root_folder / "sfincs_map.nc")

# %%
zsmax = uds["zsmax"].max(dim="timemax")
# plot rough estimation of water depth

zsmax.ugrid.plot(vmax=5)

# %%
uds_point = xu.open_dataset(root_folder / "sfincs_his.nc")

id = 3 # first observation point
uds_point['point_zs'][:,id].plot.line(x='time')
